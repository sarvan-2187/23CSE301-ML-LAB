# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('01-linear-regression-dataset.csv')

# %%
data.head()
# Out:
#    Weight  Height  Age Gender
# 0      79    1.80   35   Male
# 1      69    1.68   39   Male
# 2      73    1.82   25   Male
# 3      95    1.70   60   Male
# 4      82    1.87   27   Male

# %%
data.shape
# Out:
# (10, 4)
